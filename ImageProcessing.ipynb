# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('sea cliff.jpeg')

# %%
result = cv2.Canny(image,150,180)

# %%
plt.imshow(result,cmap='grey')

# %%
result = cv2.blur(image,(9,9))
plt.imshow(result,cmap='grey')

# %%
suduku = cv2.imread('suduku.jpeg')
gray = cv2.cvtColor(suduku,cv2.COLOR_BGR2GRAY)
corners = cv2.goodFeaturesToTrack(gray,25,0.01,10)
corners = numpy.int0(corners)
 
for i in corners:
 x,y = i.ravel()
 cv2.circle(suduku,(x,y),3,255,-1)
 
plt.imshow(suduku),plt.show()
# Out:
# /var/folders/4n/gbrmm4bs17ldvh4_ypty4z5c0000gn/T/ipykernel_13891/1379428978.py:4: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = numpy.int0(corners)
# (<matplotlib.image.AxesImage at 0x15ef46c20>, None)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('suduku.jpeg')


gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

corners = cv.goodFeaturesToTrack(gray, 250, 0.1, 3)

corners = np.int0(corners)

for i in corners:
    x, y = i.ravel()
    cv.circle(img, (x, y), 10, (0, 0, 255), -1)

img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title('Corner Detection')

plt.show()
# Out:
# /var/folders/4n/gbrmm4bs17ldvh4_ypty4z5c0000gn/T/ipykernel_13891/2672524330.py:19: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)

# %%
canny = cv2.Canny(gray,145,150)

# %%
plt.imshow(canny,cmap='grey')
